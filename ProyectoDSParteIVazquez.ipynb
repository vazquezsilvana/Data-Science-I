# %%
df
# Out:
#      Gender;Age;Work Pressure;Job Satisfaction;Sleep Duration;Dietary Habits;Have you ever had suicidal thoughts ?;Work Hours;Financial Stress;Family History of Mental Illness;Depression
# 0     Female;37;2.0;4.0;7-8 hours;Moderate;No;6;2;No;No
# 1     Male;60;4.0;3.0;5-6 hours;Unhealthy;Yes;0;4;Ye...
# 2     Female;42;2.0;3.0;5-6 hours;Moderate;No;0;2;No;No
# 3     Female;44;3.0;5.0;7-8 hours;Healthy;Yes;1;2;Ye...
# 4     Male;48;4.0;3.0;7-8 hours;Moderate;Yes;6;5;Yes;No
# 5     Female;60;1.0;4.0;7-8 hours;Unhealthy;Yes;12;3...
# 6     Female;30;4.0;2.0;More than 8 hours;Healthy;No...
# 7     Male;30;1.0;2.0;More than 8 hours;Unhealthy;Ye...
# 8     Male;56;1.0;2.0;More than 8 hours;Moderate;Yes...
# 9     Female;35;3.0;4.0;Less than 5 hours;Moderate;N...
# 10    Male;21;2.0;5.0;Less than 5 hours;Moderate;No;...
# 11    Male;57;1.0;2.0;Less than 5 hours;Healthy;No;1...
# 12      Male;54;3.0;2.0;7-8 hours;Healthy;No;11;4;No;No
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("https://raw.githubusercontent.com/vazquezsilvana/Data-Science-I/refs/heads/main/Depression-Professional-Dataset.csv")
